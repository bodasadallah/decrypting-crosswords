# %%
from datasets import load_dataset, load_from_disk,concatenate_datasets
from tqdm import tqdm

# %%
half_disjoint_path = 'data/disjoint_half_targets'
unique = 'data/unique_targets'



unique_disjoint_dataset = load_from_disk(unique)

# %%
# unique_disjoint_dataset.push_to_hub('boda/cryptic_crosswords_unique_targets')
# Out:
# ...
# Creating parquet from Arrow format:   0%|          | 0/6 [00:00<?, ?ba/s]

# %%
unique_disjoint_dataset['test']
# Out:
# Dataset({
#     features: ['labels', 'clue'],
#     num_rows: 5629
# })

# %%
original_disjoint_dataset = load_dataset('data/clue_json/guardian/word_initial_disjoint')
# Out:
# ...
# Extracting data files:   0%|          | 0/3 [00:00<?, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating validation split: 0 examples [00:00, ? examples/s]
# Generating test split: 0 examples [00:00, ? examples/s]

# %%
len(unique_disjoint_dataset['test'].unique('labels'))
# Out:
# 5629

# %%
len(original_disjoint_dataset['train'].unique('target')) + len(original_disjoint_dataset['validation'].unique('target'))
# Out:
# 42793

# %%
train_dataset = load_dataset('json', data_files='data/clue_json/guardian/word_initial_disjoint/train.json', split='train')
test_dataset = load_dataset('json', data_files='data/clue_json/guardian/word_initial_disjoint/test.json', split='train')
val_dataset = load_dataset('json', data_files='data/clue_json/guardian/word_initial_disjoint/val.json', split='train')

# %%
half_disjoint_path = 'data/disjoint_half_targets'

half_disjoint_path_dataset = load_from_disk(half_disjoint_path)

# %%
unique = 'data/unique_targets'

unique_dataset = load_from_disk(unique)

# %%
train_disjoint_dataset = concatenate_datasets([train_dataset, val_dataset])
test_disjoint_dataset = test_dataset

# %%
unique_dataset['test']['labels']
# Out:
# ['bound',
#  'messier',
#  'twee',
#  'sign on',
#  'breadcrumb',
#  'rial',
#  'baudelaire',
#  'ten commandments',
#  'enjoined',
#  'cheeseburger',
#  'prominent',
#  'keep to the right',
#  'storylines',
#  'edwards',
#  'cheri',
#  'eastern',
#  'name names',
#  'charles atlas',
#  'methinks',
#  'dirac',
#  'title page',
#  'egg glasses',
#  'get through',
#  'dross',
#  'chestnuts',
#  'yeasty',
#  'pumices',
#  'carnation',
#  'skyrocket',
#  'witter',
#  'allyl',
#  'come home',
#  'laundress',
#  'maintenance man',
#  'persimmon',
#  'residential',
#  'senora',
#  'wrong',
#  'sparrowgrass',
#  'wear down',
#  'tenable',
#  'googlies',
#  'enter',
#  'fretless',
#  'postponement',
#  'loss',
#  'sere',
#  'enrich',
#  'sticky',
#  'eschews',
#  'scorecards',
#  'aurochs',
#  'immoderate',
#  'dwarfish',
#  'remove',
#  'cutlet',
#  'pensacola',
#  'lieu',
#  'working majority',
#  'gurnet',
#  'earthling',
#  'skirted',
#  'slap up',
#  'federated',
#  'con artist',
# ...

# %%
train_disjoint_dataset.unique('target')
# Out:
# ['abed',
#  'maths',
#  'set the alarm',
#  'credit card',
#  'idiotic',
#  'peggotty',
#  'dubliner',
#  'eglantine',
#  'poet laureate',
#  'gloss',
#  'rocambole',
#  'tuning peg',
#  'morning prayer',
#  'fazed',
#  'igniting',
#  'soar',
#  'playgoer',
#  'albus',
#  'brig',
#  'kiel canal',
#  'email',
#  'clinton',
#  'avalanche',
#  'diet',
#  'kismet',
#  'keir hardie',
#  'aflutter',
#  'clarence',
#  'ipad',
#  'icing',
#  'rogue',
#  'bolt',
#  'osier',
#  'alamo',
#  'arbiter',
#  'credit',
#  'edit',
#  'diver',
#  'nuggets',
#  'smash hit',
#  'penny blacks',
#  'affirm',
#  'avail',
#  'edentate',
#  'bowels',
#  'bearskin',
#  'steer',
#  'arsenal',
#  'reason',
#  'kindle',
#  'aviarist',
#  'raccoon',
#  'asimov',
#  'reef',
#  'nuclear',
#  'traipsed',
#  'stud',
#  'the mail on sunday',
#  'rhotacism',
#  'muffs',
#  'mayflies',
#  'tycoons',
#  'distribute',
#  'rarity',
#  'omnific',
#  'bistro',
#  'gas lamp',
#  'earnest',
#  'epergne',
#  'second rate',
# ...

# %%
for t in tqdm(test_dataset['target']):
    
    assert t in unique_dataset['test']['labels']
# Out:
#   0%|          | 0/33905 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[14], line 3
#       1 for t in tqdm(test_dataset['target']):
# ----> 3     assert t in unique_dataset['test']['labels']
#
# AssertionError:

# %%
for t in tqdm(train_disjoint_dataset['target']):
    assert t in half_disjoint_path_dataset['train']['labels']
# Out:
#   1%|          | 722/108475 [00:31<1:18:25, 22.90it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 2
#       1 for t in tqdm(train_disjoint_dataset['target']):
# ----> 2     assert t in half_disjoint_path_dataset['train']['labels']
#
# File ~/.conda/envs/nlp/lib/python3.10/site-packages/datasets/arrow_dataset.py:2803, in Dataset.__getitem__(self, key)
#    2801 def __getitem__(self, key):  # noqa: F811
#    2802     """Can be used to index columns (by string names) or rows (by integer index or iterable of indices or bools)."""
# -> 2803     return self._getitem(key)
#
# File ~/.conda/envs/nlp/lib/python3.10/site-packages/datasets/arrow_dataset.py:2788, in Dataset._getitem(self, key, **kwargs)
#    2786 formatter = get_formatter(format_type, features=self._info.features, **format_kwargs)
# ...

# %%
for t in test_disjoint_dataset['target']:
    assert t in half_disjoint_path_dataset['test']['labels']
